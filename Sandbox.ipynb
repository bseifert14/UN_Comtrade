# %% [markdown]
# **Ben Seifert. UN Comtrade Data. November 26, 2017**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('comtrade (1).csv')
# Out:
# /Users/benjaminseifert/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.columns
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        '2nd Partner Code', '2nd Partner', '2nd Partner ISO',
#        'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
#        'Mode of Transport', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Qty', 'Alt Qty Unit Code', 'Alt Qty Unit', 'Alt Qty',
#        'Netweight (kg)', 'Gross weight (kg)', 'Trade Value (US$)',
#        'CIF Trade Value (US$)', 'FOB Trade Value (US$)', 'Flag'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Classification                0
# Year                          0
# Period                        0
# Period Desc.                  0
# Aggregate Level               0
# Is Leaf Code                  0
# Trade Flow Code               0
# Trade Flow                    0
# Reporter Code                 0
# Reporter                      0
# Reporter ISO                  0
# Partner Code                  0
# Partner                       0
# Partner ISO                   0
# 2nd Partner Code          50000
# 2nd Partner               50000
# 2nd Partner ISO           50000
# Customs Proc. Code        50000
# Customs                   50000
# Mode of Transport Code    50000
# Mode of Transport         50000
# Commodity Code                0
# Commodity                     0
# Qty Unit Code                 0
# Qty Unit                      0
# Qty                       50000
# Alt Qty Unit Code         50000
# Alt Qty Unit               5644
# Alt Qty                   50000
# ...

# %%
df.drop(['2nd Partner Code', '2nd Partner', '2nd Partner ISO', 'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
        'Mode of Transport', 'Qty', 'Alt Qty Unit Code', 'Alt Qty', 'Gross weight (kg)', 'CIF Trade Value (US$)',
        'FOB Trade Value (US$)'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Classification', 'Year', 'Period', 'Period Desc.', 'Aggregate Level',
#        'Is Leaf Code', 'Trade Flow Code', 'Trade Flow', 'Reporter Code',
#        'Reporter', 'Reporter ISO', 'Partner Code', 'Partner', 'Partner ISO',
#        'Commodity Code', 'Commodity', 'Qty Unit Code', 'Qty Unit',
#        'Alt Qty Unit', 'Netweight (kg)', 'Trade Value (US$)', 'Flag'],
#       dtype='object')

# %%
df.head()
# Out:
#   Classification  Year  Period  Period Desc.  Aggregate Level  Is Leaf Code  \
# 0             H3  2008    2008          2008                2             0
# 1             H3  2008    2008          2008                4             0
# 2             H3  2008    2008          2008                6             1
# 3             H3  2008    2008          2008                6             1
# 4             H3  2008    2008          2008                4             0
#
#    Trade Flow Code Trade Flow  Reporter Code Reporter  ...  Partner  \
# 0                1     Import            842      USA  ...    World
# 1                1     Import            842      USA  ...    World
# 2                1     Import            842      USA  ...    World
# 3                1     Import            842      USA  ...    World
# 4                1     Import            842      USA  ...    World
#
#    Partner ISO Commodity Code  \
# 0          WLD             01
# 1          WLD           0101
# ...

# %%
df.shape
# Out:
# (50000, 22)

# %% [markdown]
# ## Petroleum

# %%
df_new = df[df.Commodity.str.contains("Petroleum") == True]

# %%
df_new.shape
# Out:
# (132, 22)

# %%
df.Year.unique()
# Out:
# array([2008, 2009, 2010])

# %%
df_new
# Out:
#       Classification  Year  Period  Period Desc.  Aggregate Level  \
# 1101              H3  2008    2008          2008                4
# 1102              H3  2008    2008          2008                6
# 1103              H3  2008    2008          2008                4
# 1105              H3  2008    2008          2008                6
# 1108              H3  2008    2008          2008                4
# 1113              H3  2008    2008          2008                6
# 1115              H3  2008    2008          2008                6
# 1116              H3  2008    2008          2008                4
# 1117              H3  2008    2008          2008                6
# 1120              H3  2008    2008          2008                4
# 1121              H3  2008    2008          2008                6
# 1122              H3  2008    2008          2008                6
# 1123              H3  2008    2008          2008                6
# ...

# %%
sns.barplot(df_new['Year'], df_new['Trade Value (US$)'])

# %%
imports = df_new[df_new['Trade Flow'].str.contains('Import') == True]

# %%
exports = df_new[df_new['Trade Flow'].str.contains('Export') == True]

# %% [markdown]
# #### Imports

# %%
sns.barplot(imports['Year'], imports['Trade Value (US$)'])

# %% [markdown]
# #### Exports

# %%
sns.barplot(exports['Year'], exports['Trade Value (US$)'])

# %% [markdown]
# #### Lumber

# %%
lumber = df[df.Commodity.str.contains("Wood") == True]

# %%
lumber
# Out:
#       Classification  Year  Period  Period Desc.  Aggregate Level  \
# 338               H3  2008    2008          2008                6
# 2008              H3  2008    2008          2008                4
# 2009              H3  2008    2008          2008                6
# 2436              H3  2008    2008          2008                2
# 2439              H3  2008    2008          2008                6
# 2440              H3  2008    2008          2008                6
# 2442              H3  2008    2008          2008                4
# 2443              H3  2008    2008          2008                6
# 2444              H3  2008    2008          2008                6
# 2445              H3  2008    2008          2008                4
# 2446              H3  2008    2008          2008                6
# 2447              H3  2008    2008          2008                6
# 2452              H3  2008    2008          2008                6
# ...

# %%
sns.barplot(lumber['Year'], lumber['Trade Value (US$)'])

# %% [markdown]
# ** Having looked at the difference in Imports and Exports between different sectors of the US economy, I would now like to focus on countries with the top GDP to see if there are any indicators.  Below are my findings**
#
# *Date: December 5, 2017*
#
# **Note: This can be transfered to Tableu for visualization.. having difficulty integrating geospatial import/export directional arrows.  It seems like I need software that is fairly expensive.  Ive created lines for connecting each countries coordinates but I can not make it interactive.  To be finished.**

# %% [markdown]
# # Read in CSV's

# %%
usa = pd.read_csv('USA.csv')
china = pd.read_csv('China.csv')
japan = pd.read_csv('Japan.csv')
germany = pd.read_csv('Germany.csv')
uk = pd.read_csv('UK.csv')
india = pd.read_csv('India.csv')
# Out:
# /Users/benjaminseifert/anaconda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
usa[usa['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False)
# Out:
# 47903    100046547632
# 47909     29677066852
# 47906     23291413615
# 18650     15564294160
# 35413     15373758162
# 31428     15123785947
# 32983     14196344438
# 14342     13420346907
# 41450     11305952720
# 38659     11021995846
# 14535      9866906681
# 38723      8816810472
# 38780      8812493045
# 34644      7994634472
# 22351      7895775519
# 14348      7567137987
# 14541      7444531853
# 47915      7228877462
# 22396      6837511488
# 14643      6519133446
# 10626      6485908107
# 35552      5735439724
# 14351      5405584298
# 32385      5057091777
# 47236      5025122358
# 14637      4929596433
# 35471      4350397211
# 35679      4341683866
# 20597      4333426426
# 14544      4292873824
#              ...
# 29082             391
# 20195             381
# 28045             378
# 29876             371
# 31236             370
# 26396             363
# 22119             360
# 35600             356
# 27833             339
# 34069             336
# ...

# %%
usa.iloc[47903]
# Out:
# Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                           USA
# Reporter ISO                                                       USA
# Partner                                                          China
# Partner ISO                                                        CHN
# Commodity Code                                                      84
# Commodity            Nuclear reactors, boilers, machinery and mecha...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %%
print('USA:', usa.shape)
print('China:', china.shape)
print('Japan:', japan.shape)
print('Germany:', germany.shape)
print('United Kingdom:', uk.shape)
print('India:', india.shape)
# Out:
# USA: (50000, 35)
# China: (49090, 35)
# Japan: (39691, 35)
# Germany: (49962, 35)
# United Kingdom: (48454, 35)
# India: (43701, 35)

# %% [markdown]
# # Remove Null Values

# %%
china.isnull().sum()
# Out:
# Classification                0
# Year                          0
# Period                        0
# Period Desc.                  0
# Aggregate Level               0
# Is Leaf Code                  0
# Trade Flow Code               0
# Trade Flow                    0
# Reporter Code                 0
# Reporter                      0
# Reporter ISO                  0
# Partner Code                  0
# Partner                       0
# Partner ISO                   0
# 2nd Partner Code          49090
# 2nd Partner               49090
# 2nd Partner ISO           49090
# Customs Proc. Code        49090
# Customs                   49090
# Mode of Transport Code    49090
# Mode of Transport         49090
# Commodity Code                0
# Commodity                     0
# Qty Unit Code                 0
# Qty Unit                      0
# Qty                       49090
# Alt Qty Unit Code         49090
# Alt Qty Unit               3628
# Alt Qty                   49090
# ...

# %%
india.drop(['2nd Partner Code', '2nd Partner', '2nd Partner ISO', 'Customs Proc. Code', 'Customs', 'Mode of Transport Code',
        'Mode of Transport', 'Qty', 'Alt Qty Unit Code', 'Alt Qty', 'Gross weight (kg)', 'CIF Trade Value (US$)',
        'FOB Trade Value (US$)'], axis=1, inplace=True)

# %% [markdown]
# # Find top Import/ Export of each country

# %%
# Drop these columns as they don't pertain to the information we want
usa.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)
china.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)
japan.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)
india.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)
uk.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)
germany.drop(['Period Desc.', 'Classification', 'Is Leaf Code', 'Reporter Code', 'Partner Code'], axis=1, inplace=True)

# %% [markdown]
# #### USA

# %%
# locate import index
usa[usa['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 47903    100046547632
# 47909     29677066852
# 47906     23291413615
# 18650     15564294160
# 35413     15373758162
# Name: Trade Value (US$), dtype: int64

# %%
# locate export index
usa[usa['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 3527     14884936278
# 3542     14181676678
# 3558     14181634678
# 47904    11371883780
# 38660     6992448303
# Name: Trade Value (US$), dtype: int64

# %%
print('USA Import:', usa.iloc[47903])
print('---------------------------------------------------------')
print('USA Export:', usa.iloc[3527])
# Out:
# USA Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                           USA
# Reporter ISO                                                       USA
# Partner                                                          China
# Partner ISO                                                        CHN
# Commodity Code                                                      84
# Commodity            Nuclear reactors, boilers, machinery and mecha...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# #### China

# %%
china[china['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 49062    145670688473
# 49068    135120133073
# 49060     86109029796
# 40939     40452683769
# 35713     27204848510
# Name: Trade Value (US$), dtype: int64

# %%
china[china['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 49069    385677759424
# 49063    129268487384
# 40946     93158470359
# 35720     79462404249
# 49061     65214030647
# Name: Trade Value (US$), dtype: int64

# %%
print('China Import:', china.iloc[40939])
print('---------------------------------------------------------')
print('China Export:', china.iloc[40946])
# Out:
# China Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                         China
# Reporter ISO                                                       CHN
# Partner                                                          Japan
# Partner ISO                                                        JPN
# Commodity Code                                                      85
# Commodity            Electrical machinery and equipment and parts t...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# #### Japan

# %%
japan[japan['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 39661    156552583048
# 39669     69221593000
# 32288     44582243303
# 27878     26585157544
# 39663     22022455938
# Name: Trade Value (US$), dtype: int64

# %%
japan[japan['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 39670    130585866470
# 39662    113830233712
# 35160     50241779244
# 35224     39835978062
# 35261     27761077451
# Name: Trade Value (US$), dtype: int64

# %%
# the top index for import and export returned 'All Comodities' Therefore, I just went to the next best (more specific) option
print('Japan Import:', japan.iloc[32288])
print('---------------------------------------------------------')
print('Japan Export:', japan.iloc[35160])
# Out:
# Japan Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                         Japan
# Reporter ISO                                                       JPN
# Partner                                                          China
# Partner ISO                                                        CHN
# Commodity Code                                                      85
# Commodity            Electrical machinery and equipment and parts t...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# #### Germany

# %%
germany[germany['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 49932    105289752555
# 49940     65815686911
# 49938     39420806863
# 41511     31041366094
# 49934     25366076566
# Name: Trade Value (US$), dtype: int64

# %%
germany[germany['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 49941    118604735133
# 49939     94075870670
# 49933     85350435973
# 44632     30720281644
# 44630     30049799570
# Name: Trade Value (US$), dtype: int64

# %%
print('Germany Import:', germany.iloc[41511])
print('---------------------------------------------------------')
print('Germany Export:', germany.iloc[44632])
# Out:
# Germany Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                       Germany
# Reporter ISO                                                       DEU
# Partner                                                          China
# Partner ISO                                                        CHN
# Commodity Code                                                      85
# Commodity            Electrical machinery and equipment and parts t...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# #### UK

# %%
uk[uk['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 48426    88077491043
# 48424    59575883133
# 48432    57103332370
# 43287    27734982486
# 43359    20453307443
# Name: Trade Value (US$), dtype: int64

# %%
uk[uk['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 48433    61568659268
# 48427    43797383589
# 48425    18142280186
# 43294     9660278969
# 34981     9547883766
# Name: Trade Value (US$), dtype: int64

# %%
print('UK Import:', uk.iloc[43287])
print('---------------------------------------------------------')
print('UK Export:', uk.iloc[43294])
# Out:
# UK Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                United Kingdom
# Reporter ISO                                                       GBR
# Partner                                                        Germany
# Partner ISO                                                        DEU
# Commodity Code                                                      87
# Commodity            Vehicles other than railway or tramway rolling...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# #### India

# %%
india[india['Trade Flow']=='Import']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 43671    60483103314
# 36163    20871192702
# 43679    20395235271
# 43673    11499371351
# 31390    10728063761
# Name: Trade Value (US$), dtype: int64

# %%
india[india['Trade Flow']=='Export']['Trade Value (US$)'].sort_values(ascending=False).head()
# Out:
# 43680    41992468436
# 25429     9925481032
# 43672     8916072981
# 43678     8565159139
# 25467     7556513597
# Name: Trade Value (US$), dtype: int64

# %%
print('India Import:', india.iloc[36163])
print('---------------------------------------------------------')
print('India Export:', india.iloc[25429])
# Out:
# India Import: Year                                                              2016
# Period                                                            2016
# Aggregate Level                                                      2
# Trade Flow Code                                                      1
# Trade Flow                                                      Import
# Reporter                                                         India
# Reporter ISO                                                       IND
# Partner                                                          China
# Partner ISO                                                        CHN
# Commodity Code                                                      85
# Commodity            Electrical machinery and equipment and parts t...
# Qty Unit Code                                                        1
# Qty Unit                                                   No Quantity
# ...

# %% [markdown]
# # Combine DataFrames
#
# *This Section is unfinished. Date: December 3, 2017*

# %%
df_top6_GDP = pd.concat([usa, china, japan, germany, uk, india])

# %%
df_top6_GDP.columns
# Out:
# Index(['Classification', 'Year', 'Aggregate Level', 'Is Leaf Code',
#        'Trade Flow Code', 'Trade Flow', 'Reporter', 'Reporter ISO', 'Partner',
#        'Partner ISO', 'Commodity Code', 'Commodity', 'Qty Unit Code',
#        'Qty Unit', 'Alt Qty Unit', 'Netweight (kg)', 'Trade Value (US$)',
#        'Flag'],
#       dtype='object')

# %%
df_top6_GDP['Reporter'].unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'United Kingdom', 'India'], dtype=object)

# %%
df_top6_GDP.drop(['Period'],axis=1, inplace=True)

# %%
df_top6_GDP[]

# %%
df_top6_GDP.groupby[df_top6_GDP.Commodity.str.contains("Petroleum") == True]

# %%
df_top6_GDP.groupby(['Reporter'])

# %%
a = df_top6_GDP['Reporter'].groupby(df_top6_GDP['Trade Value (US$)']).max()

# %%
df_top6_GDP
